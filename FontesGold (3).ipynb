# %%
import sys
# !{sys.executable} -m pip install hdfs
# Out:
# Requirement already satisfied: hdfs in /opt/conda/lib/python3.10/site-packages (2.7.0)
# Requirement already satisfied: docopt in /opt/conda/lib/python3.10/site-packages (from hdfs) (0.6.2)
# Requirement already satisfied: requests>=2.7.0 in /opt/conda/lib/python3.10/site-packages (from hdfs) (2.28.1)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from hdfs) (1.16.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.7.0->hdfs) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.7.0->hdfs) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.7.0->hdfs) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.7.0->hdfs) (1.26.11)

# %%
pip install delta-spark
# Out:
# Requirement already satisfied: delta-spark in /opt/conda/lib/python3.10/site-packages (2.1.0)
# Requirement already satisfied: importlib-metadata>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from delta-spark) (4.11.4)
# Requirement already satisfied: pyspark<3.4.0,>=3.3.0 in /usr/local/spark-3.3.0-bin-hadoop3/python (from delta-spark) (3.3.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata>=1.0.0->delta-spark) (3.8.1)
# Requirement already satisfied: py4j==0.10.9.5 in /opt/conda/lib/python3.10/site-packages (from pyspark<3.4.0,>=3.3.0->delta-spark) (0.10.9.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pyspark.sql import SparkSession
from pyspark.sql import Row
from delta import *

# %%
from pyspark.sql import Row
from delta import *

# warehouse_location points to the default location for managed databases and tables
warehouse_location = 'hdfs://hdfs-nn:9000/Projeto/Gold'

builder = SparkSession \
    .builder \
    .appName("Python Spark SQL Hive integration example") \
    .config("spark.sql.warehouse.dir", warehouse_location) \
    .config("hive.metastore.uris", "thrift://hive-metastore:9083") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .config("spark.jars.packages", "io.delta:delta-core_2.12:1.0.0") \
    .enableHiveSupport() \

spark = spark = configure_spark_with_delta_pip(builder).getOrCreate()

# %%
spark.sql(
    """
    DROP DATABASE IF EXISTS ProjetoGold CASCADE
    """
)
spark.sql(
    """
    create database ProjetoGold location 'hdfs://hdfs-nn:9000/Projeto/Gold/ProjetoGold.db'
    """
)
# Out:
# DataFrame[]

# %%
spark.sql(
    """
    DROP DATABASE IF EXISTS Projeto_gold CASCADE
    """
)
# Out:
# DataFrame[]

# %%
from pyspark.sql.functions import substring, avg, sum

# read fontes from the silver tables
hdfs_path = "hdfs://hdfs-nn:9000//Projeto/Silver/Projeto.db/Fontes"

Fontes = spark\
             .read\
             .load(hdfs_path)

Fontes.show()
Fontes.printSchema()
# Out:
# +------------+--------------------+--------+--------------------+--------------------+-------+----------+--------------------+----------+---------+------------+----------+----------+----+--------+
# |  FountainTy|            the_geom|OBJECTID|            Position|          Collection|Painted|GISPROPNUM|            SIGNNAME|FountainCo| GISOBJID|      SYSTEM|DEPARTMENT|      Data|Year| Borough|
# +------------+--------------------+--------+--------------------+--------------------+-------+----------+--------------------+----------+---------+------------+----------+----------+----+--------+
# |  F High Low|POINT (-73.986591...|    1589|         Out in Open|02/10/2018 12:00:...|     no|      B100|Seth Low Playgrou...|         2|100038957| B100-DF0647|      B-11|02/10/2018|2018|Brooklyn|
# |           C|POINT (-73.946392...|    2917|In Shade, In Play...|05/29/2018 12:00:...|   null|      B302|     Charlie's Place|         1|100040304| B302-DF0897|      B-03|05/29/2018|2018|Brooklyn|
# |E Wheelchair|POINT (-73.924120...|      23|         Out in Open|01/11/2018 12:00:...|    yes|      B016|Maria Hernandez Park|         1|100037411| B016-DF0013|      B-04|01/11/2018|2018|Brooklyn|
# |           C|POINT (-74.011521...|    1898|       In Playground|02/15/2018 12:00:...|     no|      B052|   Leif Ericson Park|         1|100039289| B052-DF0762|      B-10|02/15/2018|2018|Brooklyn|
# |           C|POINT (-73.986470...|    2894|            In Shade|05/29/2018 12:00:...|   null|     B255G|   Butterfly Gardens|         1|100040265|B255G-DF0895|      B-07|05/29/2018|2018|Brooklyn|
# |           C|POINT (-73.899671...|      46|       In Playground|01/12/2018 12:00:...|     no|      B107|Lion's Pride Play...|         1|100037421| B107-DF0036|      B-05|01/12/2018|2018|Brooklyn|
# |           A|POINT (-73.959108...|     215|In Playground, Un...|01/18/2018 12:00:...|     no|      B043|Greenpoint Playgr...|         1|100037662| B043-DF0205|      B-01|01/18/2018|2018|Brooklyn|
# |           A|POINT (-73.971526...|     378|         Out in Open|01/22/2018 12:00:...|     no|      B073|       Prospect Park|         1|100037701| B073-DF0304|      B-19|01/22/2018|2018|Brooklyn|
# |           D|POINT (-73.959841...|     710|In Playground, Un...|01/26/2018 12:00:...|     no|      B167|La Guardia Playgr...|         1|100038115| B167-DF0482|      B-01|01/26/2018|2018|Brooklyn|
# |           E|POINT (-73.958956...|     879|         Out in Open|01/29/2018 12:00:...|     no|      B169|Coney Island Beac...|         1|100038259| B169-DF0549|      B-13|01/29/2018|2018|Brooklyn|
# |           A|POINT (-74.017157...|    1875|         Out in Open|02/15/2018 12:00:...|     no|      B060|       McKinley Park|         1|100039226| B060-DF0755|      B-10|02/15/2018|2018|Brooklyn|
# |           C|POINT (-73.863013...|      69|       In Playground|01/12/2018 12:00:...|     no|      B283|  Belmont Playground|         1|100037466| B283-DF0059|      B-05|01/12/2018|2018|Brooklyn|
# |           C|POINT (-73.887557...|     192|Out in Open, Near...|01/16/2018 12:00:...|     no|      B419|   Sutter Ballfields|         1|100037496| B419-DF0182|      B-05|01/16/2018|2018|Brooklyn|
# |           B|POINT (-73.975335...|     401|         Out in Open|01/22/2018 12:00:...|     no|      B032|    Fort Greene Park|         1|100037817| B032-DF0323|      B-02|01/22/2018|2018|Brooklyn|
# |           D|POINT (-73.925488...|     733|          Under Tree|01/26/2018 12:00:...|    yes|      B054|Lincoln Terrace /...|         1|100038157| B054-DF0495|      B-08|01/26/2018|2018|Brooklyn|
# |           A|POINT (-74.004639...|     856|       In Playground|01/29/2018 12:00:...|    yes|     B210B|   D'Emic Playground|         1|100038250|B210B-DF0530|      B-07|01/29/2018|2018|Brooklyn|
# |           A|POINT (-74.030982...|    1729|Just Outside Play...|02/12/2018 12:00:...|     no|      B066|     Owl's Head Park|         1|100039112| B066-DF0715|      B-10|02/12/2018|2018|Brooklyn|
# |E Wheelchair|POINT (-73.917475...|     501|Under Tree, In Sh...|01/23/2018 12:00:...|    yes|      B352|   Curtis Playground|         1|100037917| B352-DF0394|      B-18|01/23/2018|2018|Brooklyn|
# |           A|POINT (-73.954973...|    2107|      Near Ballfield|02/23/2018 12:00:...|    yes|      B058|       McCarren Park|         1|100039549| B058-DF0798|      B-01|02/23/2018|2018|Brooklyn|
# |           C|POINT (-73.938035...|     209|Out in Open, Near...|01/17/2018 12:00:...|     no|      B218|      Paerdegat Park|         1|100037680| B218-DF0199|      B-17|01/17/2018|2018|Brooklyn|
# +------------+--------------------+--------+--------------------+--------------------+-------+----------+--------------------+----------+---------+------------+----------+----------+----+--------+
# only showing top 20 rows
#
# root
#  |-- FountainTy: string (nullable = true)
#  |-- the_geom: string (nullable = true)
#  |-- OBJECTID: integer (nullable = true)
#  |-- Position: string (nullable = true)
#  |-- Collection: string (nullable = true)
#  |-- Painted: string (nullable = true)
#  |-- GISPROPNUM: string (nullable = true)
#  |-- SIGNNAME: string (nullable = true)
#  |-- FountainCo: integer (nullable = true)
#  |-- GISOBJID: string (nullable = true)
#  |-- SYSTEM: string (nullable = true)
#  |-- DEPARTMENT: string (nullable = true)
#  |-- Data: string (nullable = true)
#  |-- Year: integer (nullable = true)
#  |-- Borough: string (nullable = true)

# %%
# join to make a flat table with product information
#flat_mordidas_fontes_df = Fontes.join(Mordidas_Caes, (Fontes.Year == Mordidas_Caes.Year) & (Fontes.Borough == Mordidas_Caes.Borough), "inner") \
#   .drop(Fontes.Borough) \
#   .drop(Mordidas_Caes.Year) \

# %%
# create fontes table in gold
spark.sql(
    """
    DROP TABLE IF EXISTS ProjetoGold.Gold_Fontes
    """
)

spark.sql(
    """
    CREATE EXTERNAL TABLE ProjetoGold.Gold_Fontes (
        FountainTy string,
        the_geom string,
        OBJECTID INT,
        Position string,
        Collection string,
        Painted string,
        GISPROPNUM string,
        SIGNNAME string,
        Borough string,
        FountainCo INT,
        GISOBJID string,
        SYSTEM string,
        DEPARTMENT string,
        PARENTID string, 
        Data string,
        Year INT
            
    )
    USING DELTA
    LOCATION 'hdfs://hdfs-nn:9000
# |           B|POINT (-73.975335...|     401|         Out in Open|01/22/2018 12:00:...|     no|      B032|    Fort Greene Park|         1|100037817| B032-DF0323|      B-02|01/22/2018|2018|Brooklyn|
# |           D|POINT (-73.925488...|     733|          Under Tree|01/26/2018 12:00:...|    yes|      B054|Lincoln Terrace /...|         1|100038157| B054-DF0495|      B-08|01/26/2018|2018|Brooklyn|
# |           A|POINT (-74.004639...|     856|       In Playground|01/29/2018 12:00:...|    yes|     B210B|   D'Emic Playground|         1|100038250|B210B-DF0530|      B-07|01/29/2018|2018|Brooklyn|
# |           A|POINT (-74.030982...|    1729|Just Outside Play...|02/12/2018 12:00:...|     no|      B066|     Owl's Head Park|         1|100039112| B066-DF0715|      B-10|02/12/2018|2018|Brooklyn|
# |E Wheelchair|POINT (-73.917475...|     501|Under Tree, In Sh...|01/23/2018 12:00:...|    yes|      B352|   Curtis Playground|         1|100037917| B352-DF0394|      B-18|01/23/2018|2018|Brooklyn|
# |           A|POINT (-73.954973...|    2107|      Near Ballfield|02/23/2018 12:00:...|    yes|      B058|       McCarren Park|         1|100039549| B058-DF0798|      B-01|02/23/2018|2018|Brooklyn|
# |           C|POINT (-73.938035...|     209|Out in Open, Near...|01/17/2018 12:00:...|     no|      B218|      Paerdegat Park|         1|100037680| B218-DF0199|      B-17|01/17/2018|2018|Brooklyn|
# +------------+--------------------+--------+--------------------+--------------------+-------+----------+--------------------+----------+---------+------------+----------+----------+----+--------+
# only showing top 20 rows
#
# root
#  |-- FountainTy: string (nullable = true)
#  |-- the_geom: string (nullable = true)
#  |-- OBJECTID: integer (nullable = true)
#  |-- Position: string (nullable = true)
#  |-- Collection: string (nullable = true)
#  |-- Painted: string (nullable = true)
#  |-- GISPROPNUM: string (nullable = true)
#  |-- SIGNNAME: string (nullable = true)
#  |-- FountainCo: integer (nullable = true)
#  |-- GISOBJID: string (nullable = true)
#  |-- SYSTEM: string (nullable = true)
#  |-- DEPARTMENT: string (nullable = true)
#  |-- Data: string (nullable = true)
#  |-- Year: integer (nullable = true)
#  |-- Borough: string (nullable = true)

# %%
Gold_Fontes.toPandas()
# Out:
#         FountainTy                                       the_geom  OBJECTID  \
# 0       F High Low   POINT (-73.98659181365889 40.60753207315604)      1589
# 1                C   POINT (-73.94639259466328 40.69933443616386)      2917
# 2     E Wheelchair  POINT (-73.92412001948213 40.703148631662614)        23
# 3                C  POINT (-74.01152114448477 40.630582530228764)      1898
# 4                C  POINT (-73.98647089425904 40.660201255822955)      2894
# ...            ...                                            ...       ...
# 3115  E Wheelchair    POINT (-74.0792508385633 40.62266148329357)      1533
# 3116             D  POINT (-74.21031591361488 40.533181277394675)      1868
# 3117             D  POINT (-74.09878669564895 40.613386552308874)      1762
# 3118             A  POINT (-74.16297563648502 40.616399379236725)      1427
# 3119             D  POINT (-74.07461258089018 40.637163189742914)      1968
#
#                      Position                    Collection Painted  \
# 0                 Out in Open  02/10/2018 12:00:00 AM +0000      no
# 1     In Shade, In Playground  05/29/2018 12:00:00 AM +0000    None
# 2                 Out in Open  01/11/2018 12:00:00 AM +0000     yes
# 3               In Playground  02/15/2018 12:00:00 AM +0000      no
# 4                    In Shade  05/29/2018 12:00:00 AM +0000    None
# ...                       ...                           ...     ...
# 3115            In Playground  02/08/2018 12:00:00 AM +0000     yes
# 3116           Near Ballfield  02/15/2018 12:00:00 AM +0000     yes
# 3117              Out in Open  02/13/2018 12:00:00 AM +0000      no
# 3118           Near Ballfield  02/05/2018 12:00:00 AM +0000     yes
# 3119              Out in Open  02/17/2018 12:00:00 AM +0000      no
#
#      GISPROPNUM                            SIGNNAME  FountainCo   GISOBJID  \
# 0          B100  Seth Low Playground/ Bealin Square           2  100038957
# 1          B302                     Charlie's Place           1  100040304
# 2          B016                Maria Hernandez Park           1  100037411
# 3          B052                   Leif Ericson Park           1  100039289
# 4         B255G                   Butterfly Gardens           1  100040265
# ...         ...                                 ...         ...        ...
# 3115       R061                Stapleton Playground           1  100038927
# 3116       R106                   Bloomingdale Park           1  100039195
# 3117       R069                  Terrace Playground           1  100039136
# 3118      R075A                  Father Macris Park           1  100038865
# 3119       R043                          Lyons Pool           1  100039317
#
#             SYSTEM DEPARTMENT        Data  Year        Borough
# 0      B100-DF0647       B-11  02/10/2018  2018       Brooklyn
# 1      B302-DF0897       B-03  05/29/2018  2018       Brooklyn
# 2      B016-DF0013       B-04  01/11/2018  2018       Brooklyn
# 3      B052-DF0762       B-10  02/15/2018  2018       Brooklyn
# 4     B255G-DF0895       B-07  05/29/2018  2018       Brooklyn
# ...            ...        ...         ...   ...            ...
# 3115   R061-DF0068       R-01  02/08/2018  2018  Staten Island
# 3116   R106-DF0138       R-03  02/15/2018  2018  Staten Island
# 3117   R069-DF0110       R-01  02/13/2018  2018  Staten Island
# 3118  R075A-DF0021       R-02  02/05/2018  2018  Staten Island
# 3119   R043-DF0171       R-01  02/17/2018  2018  Staten Island
#
# [3120 rows x 15 columns]

# %%
# write to delta table
Gold_Fontes \
    .select ("FountainTy", "the_geom", "OBJECTID", "Position", "Collection", "Painted", "GISPROPNUM", "SIGNNAME", "Borough", "FountainCo", "GISOBJID", "SYSTEM", "DEPARTMENT", "Data", "Year") \
    .write  \
    .format("delta") \
    .mode("overwrite") \
    .save("hdfs://hdfs-nn:9000/Projeto/Gold/ProjetoGold.db/Gold_Fontes/")

# %%
spark.sql("""
GENERATE symlink_format_manifest FOR TABLE delta.`hdfs://hdfs-nn:9000/Projeto/Gold/ProjetoGold.db/Gold_Fontes/`
""").show()
# Out:
# ++
# ||
# ++
# ++

# %%
spark.sql("""
DROP TABLE IF EXISTS ProjetoGold.Gold_Fontes_Presto 
""").show()

spark.sql("""
    CREATE EXTERNAL TABLE ProjetoGold.Gold_Fontes_Presto (
       FountainTy string,
        the_geom string,
        OBJECTID INT,
        Position string,
        Collection string,
        Painted string,
        GISPROPNUM string,
        SIGNNAME string,
        Borough string,
        FountainCo INT,
        GISOBJID string,
        SYSTEM string,
        DEPARTMENT string,
        PARENTID string, 
        Data string,
        Year INT
        
)
ROW FORMAT SERDE 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe'
STORED AS INPUTFORMAT 'org.apache.hadoop.hive.ql.io.SymlinkTextInputFormat'
OUTPUTFORMAT 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat'
LOCATION 'hdfs://hdfs-nn:9000/Projeto/Gold/ProjetoGold.db/Gold_Fontes/_symlink_format_manifest/'
""").show()
# Out:
# ++
# ||
# ++
# ++
#
# ++
# ||
# ++
# ++
